# %% [markdown]
# <a href="https://colab.research.google.com/github/ServAlex/JupiterNotebooks/blob/master/vae_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Input, Dense, Lambda, Dropout
from keras.models import Model
from keras.datasets import mnist
from keras import objectives
from keras import backend as K
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
#matplotlib inline
import numpy as np
from scipy.stats import norm
from keras.callbacks import EarlyStopping

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
plt.figure(figsize=(12,12))
for i in range(39):
    ax = plt.subplot(10, 13, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

# %%
x_train = x_train.astype("float32") / 255 
x_test = x_test.astype("float32") / 255 
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))) 
x_test = x_test.reshape((len(x_test), np.prod(x_train.shape[1:])))

print('x train shape', x_train.shape) 
print('x test shape', x_test.shape)

n_hidden = 128*2*2

z_dim = 2 
batch_size_count = 500 
epochs_count = 400
beta = 1.5 
is_training = True

dropoutLevel

layer_name_mu = 'layer_mu' 
layer_name_log_var = 'layer_log_var'

img_dim = x_train.shape[1]

print('image dim\t', img_dim)
# Out:
# x train shape (60000, 784)
# x test shape (10000, 784)
# image dim
# 784

# %%
input_img = Input(shape=(img_dim,))
print('input image shape')
print(input_img.shape)

#encoder
encoded = Dense(n_hidden, activation='relu')(input_img)
print('encoder stage 1 shape')
print(encoded.shape)
encoded = Dropout(0.4)(encoded)

encoded = Dense(n_hidden//2, activation='relu')(encoded)
print('encoder stage 2 shape')
print(encoded.shape)
encoded = Dropout(0.3)(encoded)


encoded = Dense(n_hidden//4, activation='relu')(encoded)
print('encoder stage 3 shape')
print(encoded.shape)
encoded = Dropout(0.2)(encoded)

mu = Dense(z_dim, name = layer_name_mu)(encoded)
print('mu shape')
print(mu.shape)
#mu.name = layer_name_mu

log_var = Dense(z_dim, name = layer_name_log_var)(encoded)
print('log_var shape')
print(log_var.shape)
#log_var.name = layer_name_log_var
# Out:
# input image shape
# (?, 784)
# encoder stage 1 shape
# (?, 512)
# encoder stage 2 shape
# (?, 256)
# encoder stage 3 shape
# (?, 128)
# mu shape
# (?, 2)
# log_var shape
# (?, 2)

# %%
def sampling(args):
    mu, log_var = args
    eps = tf.random.normal(shape=(batch_size_count, z_dim), mean=0., stddev=1.0)
    print('eps shape\t', eps.shape)
    print('mu shape\t', mu.shape)
    print('log_var shape\t', log_var.shape)
    return mu + K.exp(log_var) * eps

z = Lambda(sampling, output_shape=(z_dim,))([mu, log_var])
print('z shape \t', z.shape)
# Out:
# eps shape	 (500, 2)
# mu shape	 (?, 2)
# log_var shape	 (?, 2)
# z shape 	 (500, 2)

# %%
# decoder
z_decoder1 = Dense(n_hidden//4, activation='relu')
z_decoder2 = Dense(n_hidden//2, activation='relu')
z_decoder3 = Dense(n_hidden, activation='relu')
y_decoder = Dense(img_dim, activation='sigmoid')

z_decoded = z_decoder1(z)
z_decoded = Dropout(0.2)(z_decoded)
print('decoded stage 1 shape \t', z_decoded.shape)

z_decoded = z_decoder2(z_decoded)
z_decoded = Dropout(0.3)(z_decoded)
print('decoded stage 2 shape \t', z_decoded.shape)

z_decoded = z_decoder3(z_decoded)
z_decoded = Dropout(0.4)(z_decoded)
print('decoded stage 3 shape \t', z_decoded.shape)

y = y_decoder(z_decoded)
print('y shape \t', y.shape)
# Out:
# decoded stage 1 shape 	 (500, 128)
# decoded stage 2 shape 	 (500, 256)
# decoded stage 3 shape 	 (500, 512)
# y shape 	 (500, 784)

# %%
# loss
reconstruction_loss = objectives.binary_crossentropy(input_img, y) * img_dim
kl_loss = K.sum(K.square(mu) + K.exp(log_var) - log_var - 1, axis = -1)
vae_loss = reconstruction_loss + beta*kl_loss

# build model
vae = Model(input_img, y)
vae.add_loss(vae_loss)
vae.compile(optimizer='Adadelta')   #'Adadelta', 'rmsprop''Adagrad'
vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 784)          0
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 512)          401920      input_10[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 512)          0           dense_36[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 256)          131328      dropout_29[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 256)          0           dense_37[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 128)          32896       dropout_30[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 128)          0           dense_38[0][0]
# __________________________________________________________________________________________________
# layer_mu (Dense)                (None, 2)            258         dropout_31[0][0]
# __________________________________________________________________________________________________
# layer_log_var (Dense)           (None, 2)            258         dropout_31[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 2)            0           layer_mu[0][0]
#                                                                  layer_log_var[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 128)          384         lambda_6[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 128)          0           dense_39[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 256)          33024       dropout_32[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 256)          0           dense_40[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 512)          131584      dropout_33[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 512)          0           dense_41[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 784)          402192      dropout_34[0][0]
# ==================================================================================================
# Total params: 1,133,844
# Trainable params: 1,133,844
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# fitting
history = vae.fit(x_train,
       shuffle=True,
       epochs=epochs_count,
       batch_size=batch_size_count,
       validation_data=(x_test, None), 
       verbose=1)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/400
# 60000/60000 [==============================] - 2s 40us/step - loss: 229.3640 - val_loss: 199.5362
# Epoch 2/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 200.5939 - val_loss: 196.4111
# Epoch 3/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 197.9760 - val_loss: 194.3275
# Epoch 4/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 196.4974 - val_loss: 194.4772
# Epoch 5/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 195.5531 - val_loss: 193.4400
# Epoch 6/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 195.0156 - val_loss: 193.7463
# Epoch 7/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 194.3022 - val_loss: 194.1216
# Epoch 8/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 194.0111 - val_loss: 193.3978
# Epoch 9/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 193.3096 - val_loss: 194.9747
# Epoch 10/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 192.5188 - val_loss: 190.6747
# Epoch 11/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 190.7694 - val_loss: 185.4403
# Epoch 12/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 186.2071 - val_loss: 180.6893
# Epoch 13/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 182.8389 - val_loss: 177.9485
# Epoch 14/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 180.1192 - val_loss: 178.5239
# Epoch 15/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 177.8601 - val_loss: 172.1831
# Epoch 16/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 175.3840 - val_loss: 171.1326
# Epoch 17/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 173.6065 - val_loss: 169.0027
# Epoch 18/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 172.4888 - val_loss: 169.0701
# Epoch 19/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 171.5211 - val_loss: 166.7047
# Epoch 20/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 170.6089 - val_loss: 165.6582
# Epoch 21/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 169.9687 - val_loss: 164.4068
# Epoch 22/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 169.3491 - val_loss: 164.2662
# Epoch 23/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 168.7656 - val_loss: 163.5658
# Epoch 24/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 168.1736 - val_loss: 162.4973
# Epoch 25/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 167.5441 - val_loss: 160.7826
# Epoch 26/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 166.4049 - val_loss: 160.8397
# Epoch 27/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 165.3654 - val_loss: 158.2555
# Epoch 28/400
# 60000/60000 [==============================] - 1s 15us/step - loss:
400
# 60000/60000 [==============================] - 1s 15us/step - loss: 152.4083 - val_loss: 145.4955
# Epoch 85/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 152.3336 - val_loss: 145.2328
# Epoch 86/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 152.0168 - val_loss: 145.7878
# Epoch 87/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 152.0570 - val_loss: 144.9989
# Epoch 88/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 152.0149 - val_loss: 146.0845
# Epoch 89/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 152.0307 - val_loss: 146.0030
# Epoch 90/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.9777 - val_loss: 145.1093
# Epoch 91/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.6912 - val_loss: 145.2111
# Epoch 92/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.8744 - val_loss: 145.1512
# Epoch 93/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.7914 - val_loss: 146.3734
# Epoch 94/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 151.6380 - val_loss: 145.0959
# Epoch 95/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 151.6786 - val_loss: 145.9665
# Epoch 96/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.4084 - val_loss: 144.8022
# Epoch 97/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.2885 - val_loss: 145.6098
# Epoch 98/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 151.4677 - val_loss: 144.8864
# Epoch 99/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.4228 - val_loss: 144.6846
# Epoch 100/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.3080 - val_loss: 144.5005
# Epoch 101/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.2811 - val_loss: 145.0775
# Epoch 102/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 151.2574 - val_loss: 145.1179
# Epoch 103/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.0720 - val_loss: 145.0768
# Epoch 104/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.0462 - val_loss: 144.3196
# Epoch 105/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.0621 - val_loss: 144.1840
# Epoch 106/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.3530 - val_loss: 145.1481
# Epoch 107/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 151.0917 - val_loss: 144.0844
# Epoch 108/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.0674 - val_loss: 144.3055
# Epoch 109/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.4966 - val_loss: 144.5269
# Epoch 110/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.3284 - val_loss: 144.1893
# Epoch 111/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.8404 - val_loss: 144.6279
# Epoch 112/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 150.8370 - val_loss: 144.7506
# Epoch 113/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.6778 - val_loss: 143.8085
# Epoch 114/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.6196 - val_loss: 143.7026
# Epoch 115/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.6265 - val_loss: 144.2650
# Epoch 116/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.7449 - val_loss: 144.0544
# Epoch 117/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.6895 - val_loss: 144.3912
# Epoch 118/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.5789 - val_loss: 143.8811
# Epoch 119/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 150.4625 - val_loss: 143.6163
# Epoch 120/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.5822 - val_loss: 143.8801
# Epoch 121/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.5728 - val_loss: 143.9954
# Epoch 122/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.6541 - val_loss: 144.1442
# Epoch 123/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 150.5114 - val_loss: 143.9141
# Epoch 124/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.5231 - val_loss: 143.4783
# Epoch 125/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.5421 - val_loss: 143.8438
# Epoch 126/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.3829 - val_loss: 144.9611
# Epoch 127/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 151.6739 - val_loss: 146.1263
# Epoch 128/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.7298 - val_loss: 143.3568
# Epoch 129/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 150.4492 - val_loss: 144.4001
# Epoch 130/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.2923 - val_loss: 144.8035
# Epoch 131/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.3011 - val_loss: 144.0989
# Epoch 132/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.2859 - val_loss: 143.8671
# Epoch 133/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.4519 - val_loss: 143.7951
# Epoch 134/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.5946 - val_loss: 143.8592
# Epoch 135/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.1761 - val_loss: 144.6662
# Epoch 136/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 149.9763 - val_loss: 143.1378
# Epoch 137/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.0719 - val_loss: 143.2419
# Epoch 138/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 150.0764 - val_loss: 143.1295
# Epoch 139/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 149.9258 - val_loss: 143.4773
# Epoch 140/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 150.0842 - val_loss: 143.2324
# Epoch 141/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.0881 - val_loss: 143.5943
# Epoch 142/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 150.0584 - val_loss: 143.0715
# Epoch 143/400
# 60000/60000 [==============================] - 1s 16us/step - loss: 149
400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.3259 - val_loss: 142.2535
# Epoch 390/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.4006 - val_loss: 141.8642
# Epoch 391/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.4341 - val_loss: 141.7671
# Epoch 392/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.4545 - val_loss: 142.9202
# Epoch 393/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.6482 - val_loss: 142.8001
# Epoch 394/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.5636 - val_loss: 142.1394
# Epoch 395/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.7522 - val_loss: 142.1592
# Epoch 396/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.4957 - val_loss: 142.2924
# Epoch 397/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.3256 - val_loss: 142.4480
# Epoch 398/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.2336 - val_loss: 141.7397
# Epoch 399/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.3848 - val_loss: 142.3779
# Epoch 400/400
# 60000/60000 [==============================] - 1s 15us/step - loss: 148.2600 - val_loss: 142.2172

# %%
выintermediate_layer_model_mu = Model(inputs=vae.input, outputs=vae.get_layer(layer_name_mu).output)
intermediate_output_mu = intermediate_layer_model_mu.predict(x_test)

intermediate_layer_model_var_log = Model(inputs=vae.input, outputs=vae.get_layer(layer_name_log_var).output)
intermediate_output_var_log = intermediate_layer_model_var_log.predict(x_test)

# %%
intermediate_output_mu
# Out:
# array([[-0.20879656, -1.4130346 ],
#        [ 1.7091228 ,  0.2652474 ],
#        [-1.6772233 ,  1.4083909 ],
#        ...,
#        [-0.3294593 , -0.45888335],
#        [-0.7349786 , -0.10982437],
#        [ 0.11063282, -0.08079021]], dtype=float32)

# %%
print(x_test.shape)

x_test_latent = intermediate_output_mu
plt.figure(figsize=(10, 10))
plt.hsv()
plt.scatter(x_test_latent[:, 0], x_test_latent[:, 1], c=y_test)
plt.colorbar()
plt.show()
# Out:
# (10000, 784)

# %%
x_test_latent = intermediate_output_var_log

# %%
print(x_test.shape)

x_test_latent = intermediate_output_var_log
plt.figure(figsize=(10, 10))
plt.hsv()
plt.scatter(x_test_latent[:, 0], x_test_latent[:, 1], c=y_test)
plt.colorbar()
plt.show()
# Out:
# (10000, 784)

# %%
# Plot training & validation loss values
plt.figure(figsize=(20, 15))
plt.plot([a[1] for a in history.history['loss']])
plt.plot([a[1] for a in history.history['val_loss']])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
print(np.shape(history.history['loss']))
print(type(history.history['loss'][1]))
# Out:
# (400, 500)
# <class 'numpy.ndarray'>

# %%
decoder_input = Input(shape=(z_dim,))
_z_decoded = z_decoder1(decoder_input)
_z_decoded = z_decoder2(_z_decoded)
_z_decoded = z_decoder3(_z_decoded)
_y = y_decoder(_z_decoded)
generator = Model(decoder_input, _y)
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 2)                 0
# _________________________________________________________________
# dense_39 (Dense)             (None, 128)               384
# _________________________________________________________________
# dense_40 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_41 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_42 (Dense)             (None, 784)               402192
# =================================================================
# Total params: 567,184
# Trainable params: 567,184
# Non-trainable params: 0
# _________________________________________________________________

# %%
n = 20 # figure with 15x15 digits
digit_size = 28

figure = np.zeros((digit_size * n, digit_size * n))
grid_x = norm.ppf(np.linspace(0.01, 0.99, n)) 
grid_y = norm.ppf(np.linspace(0.01, 0.99, n))

plt.figure(figsize=(15,15))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([xi, yi])
        z_sample = np.expand_dims(z_sample, axis = 0)

        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)

        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit
plt.imshow(figure,  cmap='Greys_r')
